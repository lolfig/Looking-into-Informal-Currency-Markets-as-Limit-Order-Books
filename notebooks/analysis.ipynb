# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scienceplots
import json

plt.style.use('science')

# %%
data = pd.read_pickle("/home/figal/Projects/cuba_fx_market/data/analytics/analytics.pickle")

# %%
data.head(6)
# Out:
#                                             Compras_ordenadas  \
# 2021-07-23  precio_compra
# 55.0    21300.0
# 60.0    40290.0
# ...
# 2021-07-24  precio_compra
# 55.0     2700.0
# 60.0    34570.0
# ...
# 2021-07-25  precio_compra
# 55.0    10250.0
# 60.0    55900.0
# ...
# 2021-07-26  precio_compra
# 55.0     6850.0
# 60.0    31820.0
# ...
# 2021-07-27  precio_compra
# 55.0     15970.0
# 60.0    162050....
# 2021-07-28  precio_compra
# 55.0     5270.0
# 60.0    94855.0
# ...
#
#                                              Ventas_ordenadas  \
# 2021-07-23  precio_venta
# 55.0      2000.0
# 60.0    180415.0...
# 2021-07-24  precio_venta
# 55.0      1635.0
# 60.0    141715.0...
# 2021-07-25  precio_venta
# 60.0    166270.0
# 65.0     27635.0...
# 2021-07-26  precio_venta
# 60.0     168580.0
# 65.0      27980...
# 2021-07-27  precio_venta
# 60.0    124700.0
# 65.0      4810.0...
# 2021-07-28  precio_venta
# 50.0      1020.0
# 55.0      5440.0...
#
# ...

# %%
serie_price_mar = data['Marginal_Data'][1:].apply(lambda x: x[0]['price_mar'])
serie_vol_compra = data['Volumen_Compra'][1:]
serie_vol_venta = data['Volumen_Venta'][1:]

# %%
plt.figure(figsize=(10,3))
plt.plot(serie_price_mar)
plt.show()
